# %% [markdown]
# # Predicting emissions

# %% [markdown]
# ## Simple CNN from the original images

# %%
path_annotrain = "../datasets/datasets_train/train_annotation/_annotation.csv"

train_annotation = pd.read_csv(path_annotrain, index_col=0)
train_annotation = train_annotation[train_annotation["models"]!=" "]

df = pd.merge(train_annotation, emission_data, "inner", on="models")
df.head()
# Out:
#          im_name  x_min  y_min   x_max  y_max class                    models  \
# 0  107347968.jpg   40.0  244.0  1144.0  637.0   car  Audi S5 Convertible 2012
# 1  109641728.jpg  278.0  284.0   917.0  539.0   car  Audi S5 Convertible 2012
# 2  111214592.jpg   29.0  133.0   350.0  263.0   car  Audi S5 Convertible 2012
# 3  110821376.jpg   34.0   71.0   245.0  160.0   car  Audi S5 Convertible 2012
# 4  109379584.jpg   99.0  147.0   712.0  516.0   car  Audi S5 Convertible 2012
#
#   Brand  year  Average Urban Consumption  Average extra-urban consumption  \
# 0  Audi  2012                    7.90636                           5.3053
# 1  Audi  2012                    7.90636                           5.3053
# 2  Audi  2012                    7.90636                           5.3053
# 3  Audi  2012                    7.90636                           5.3053
# 4  Audi  2012                    7.90636                           5.3053
#
#    Average mixed consumption  Average of CO2 (g per km) Average CO type I  \
# 0                   6.262544                 153.533569       0,298187279
# 1                   6.262544                 153.533569       0,298187279
# 2                   6.262544                 153.533569       0,298187279
# 3                   6.262544                 153.533569       0,298187279
# 4                   6.262544                 153.533569       0,298187279
#
#       category
# 0  Convertible
# 1  Convertible
# 2  Convertible
# 3  Convertible
# 4  Convertible

# %%
from sklearn.metrics import mean_squared_error

print("Regression baseline :", mean_squared_error([df["Average of CO2 (g per km)"].mean() for _ in range(df.shape[0])], 
                                                  df["Average of CO2 (g per km)"])/df.shape[0])
# Out:
# Regression baseline : 4.025270303726511

# %%
import time
import torch
import torchvision
from torchvision.transforms import *
import torch.nn.functional as F
from PIL import Image

batch_size=64

class MyDataset(torch.utils.data.Dataset):
    def __init__(self, dataframe):
        self.dataframe = dataframe

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        row = self.dataframe.iloc[index]
        c = torchvision.transforms.Compose([Grayscale(),
                                            RandomHorizontalFlip(),
                                            RandomPerspective(),
                                            RandomRotation(degrees=(0, 180)),
                                            RandomVerticalFlip(),
                                            Resize((96,96)),
                                            functional.to_tensor])
        return (
            c(Image.open("../datasets/datasets_train/train/"+row["im_name"])),
            row["Average of CO2 (g per km)"],
        )

dataset = MyDataset(df)

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

train_set, val_set = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(dataset=train_set, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(dataset=val_set, batch_size=batch_size)

class ConvNet(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(1, 3, 3, padding='same')
        self.pool = torch.nn.MaxPool2d(2, 2)
        self.conv2 = torch.nn.Conv2d(3, 6, 3, padding='same')
        self.conv3 = torch.nn.Conv2d(6, 12, 3, padding='same')
        self.fc = torch.nn.Linear(1728, 1)
        self.dropout = torch.nn.Dropout()


    def forward(self, x):
        x = x.view(-1,1,96,96)
        x = self.dropout(self.pool(F.relu(self.conv1(x))))
        x = self.dropout(self.pool(F.relu(self.conv2(x))))
        x = self.dropout(self.pool(F.relu(self.conv3(x))))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = self.fc(x)
        return x

my_model = ConvNet()

optimizer = torch.optim.Adam(my_model.parameters(), lr=3e-4)
# optimizer = torch.optim.SGD(model.parameters(), lr=0.5e-1)

criterion = torch.nn.MSELoss()

loss_l_train = []
loss_l_val = []
nb_epoch = 200

for num_epoch in range(nb_epoch):
    t0 = time.time()
    my_model.train()
    running_loss = 0
    total = 0
    for i, (inputs, labels) in enumerate(train_loader):
        outputs = my_model(inputs) # Forward pass: Compute predicted y by passing  x to the model          
        labels = labels.unsqueeze(1).float()
        loss = criterion(outputs,labels) # Compute loss 

        optimizer.zero_grad() # re-init the gradients (otherwise they are cumulated)
        loss.backward() # perform back-propagation
        optimizer.step() # update the weights

        running_loss += loss.item()
        
        total += labels.size(0)

    loss_l_train.append(running_loss/total)

    my_model.eval()
    running_loss_val = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            outputs = my_model(inputs)  
            labels = labels.unsqueeze(1).float()
            loss = criterion(outputs,labels)

            running_loss_val += loss.item()

            total += labels.size(0)

    loss_l_val.append(running_loss_val/total)

    if loss_l_val[-1] == min(loss_l_val):
        print("Saving best model")
        torch.save(my_model, 'models/best-reg.pt')
        torch.save(my_model.state_dict(), 'models/best-reg-parameters.pt')

    print(f'epoch {num_epoch} : train loss {loss_l_train[-1]:.5f}, val loss {loss_l_val[-1]:.5f}, time {time.time()-t0:.2f}s')
# Out:
# Saving best model
# epoch 0 : train loss 725.86420, val loss 897.27581, time 20.14s
# Saving best model
# epoch 1 : train loss 706.61034, val loss 885.22564, time 18.22s
# Saving best model
# epoch 2 : train loss 666.85862, val loss 853.82938, time 18.40s
# Saving best model
# epoch 3 : train loss 590.55086, val loss 783.64893, time 17.76s
# Saving best model
# epoch 4 : train loss 462.48929, val loss 655.61792, time 17.96s
# Saving best model
# epoch 5 : train loss 290.37592, val loss 457.51686, time 18.36s
# Saving best model
# epoch 6 : train loss 140.57691, val loss 273.13351, time 18.11s
# Saving best model
# epoch 7 : train loss 109.15769, val loss 225.03036, time 18.03s
# epoch 8 : train loss 111.39893, val loss 251.97196, time 18.61s
# epoch 9 : train loss 105.73188, val loss 253.94425, time 17.64s
# epoch 10 : train loss 104.47991, val loss 245.86983, time 18.05s
# epoch 11 : train loss 100.95169, val loss 242.87257, time 18.36s
# epoch 12 : train loss 102.26520, val loss 238.15772, time 19.25s
# epoch 13 : train loss 100.20787, val loss 244.23672, time 20.00s
# epoch 14 : train loss 98.55330, val loss 247.85547, time 17.95s
# epoch 15 : train loss 99.34947, val loss 248.27097, time 18.60s
# epoch 16 : train loss 101.43247, val loss 239.58411, time 17.90s
# epoch 17 : train loss 97.47353, val loss 232.64966, time 17.79s
# epoch 18 : train loss 98.00261, val loss 235.66508, time 22.69s
# epoch 19 : train loss 96.91827, val loss 237.56719, time 19.34s
# epoch 20 : train loss 96.26239, val loss 241.79348, time 19.22s
# epoch 21 : train loss 96.38005, val loss 240.96178, time 18.39s
# epoch 22 : train loss 96.20791, val loss 237.19270, time 18.05s
# epoch 23 : train loss 94.50674, val loss 237.53452, time 18.40s
# epoch 24 : train loss 95.75954, val loss 239.65718, time 18.22s
# epoch 25 : train loss 94.24461, val loss 240.68270, time 17.97s
# epoch 26 : train loss 94.27609, val loss 238.85909, time 18.28s
# epoch 27 : train loss 92.03849, val loss 241.67461, time 18.88s
# epoch 28 : train loss 93.16161, val loss 238.26592, time 17.81s
# epoch 29 : train loss 90.46831, val loss 239.95054, time 18.25s
# epoch 30 : train loss 90.86672, val loss 235.97423, time 17.75s
# epoch 31 : train loss 89.19673, val loss 234.64226, time 18.01s
# epoch 32 : train loss 90.22835, val loss 231.41357, time 18.09s
# epoch 33 : train loss 89.45897, val loss 231.15495, time 18.46s
# epoch 34 : train loss 91.44896, val loss 231.32442, time 17.85s
# epoch 35 : train loss 90.42149, val loss 230.53880, time 18.59s
# epoch 36 : train loss 90.48575, val loss 230.37441, time 18.60s
# epoch 37 : train loss 90.42641, val loss 234.37332, time 18.36s
# epoch 38 : train loss 89.21496, val loss 230.46966, time 17.50s
# epoch 39 : train loss 88.81771, val loss 231.84832, time 18.29s
# epoch 40 : train loss 89.66263, val loss 230.91965, time 18.38s
# epoch 41 : train loss 88.92426, val loss 227.73931, time 18.56s
# epoch 42 : train loss 88.74726, val loss 230.41516, time 18.47s
# epoch 43 : train loss 89.72449, val loss 225.68034, time 17.40s
# Saving best model
# epoch 44 : train loss 87.58899, val loss 224.33290, time 17.90s
# epoch 45 : train loss 88.82226, val loss 226.28578, time 17.37s
# epoch 46 : train loss 88.13517, val loss 225.64051, time 17.97s
# epoch 47 : train loss 88.57876, val loss 227.36294, time 18.47s
# epoch 48 : train loss 89.20788, val loss 225.21081, time 17.54s
# epoch 49 : train loss 87.61652, val loss 224.36343, time 18.03s
# Saving best model
# epoch 50 : train loss 88.17631, val loss 223.53231, time 17.70s
# Saving best model
# epoch 51 : train loss 88.04158, val loss 222.38452, time 18.16s
# epoch 52 : train loss 88.37707, val loss 222.93078, time 17.04s
# epoch 53 : train loss 88.00234, val loss 222.74783, time 17.75s
# epoch 54 : train loss 87.58977, val loss 222.62219, time 17.21s
# Saving best model
# epoch 55 : train loss 87.78499, val loss 220.55035, time 17.69s
# epoch 56 : train loss 87.59197, val loss 221.41249, time 17.95s
# epoch 57 : train loss 88.25384, val loss 220.85049, time 17.51s
# epoch 58 : train loss 87.33965, val loss 220.76070, time 17.68s
# Saving best model
# epoch 59 : train loss 87.86108, val loss 220.05808, time 17.80s
# epoch 60 : train loss 87.36595, val loss 222.56313, time 17.57s
# Saving best model
# epoch 61 : train loss 87.10503, val loss 217.77627, time 18.20s
# epoch 62 : train loss 87.48219, val loss 222.66197, time 17.81s
# epoch 63 : train loss 87.52121, val loss 220.03832, time 17.38s
# epoch 64 : train loss 87.73409, val loss 219.02981, time 18.12s
# epoch 65 : train loss 87.50161, val loss 221.63546, time 17.48s
# epoch 66 : train loss 86.83558, val loss 218.99340, time 17.65s
# epoch 67 : train loss 87.42397, val loss 220.67471, time 17.64s
# epoch 68 : train loss 88.10192, val loss 219.89533, time 16.70s
# epoch 69 : train loss 87.45350, val loss 220.88682, time 18.40s
# epoch 70 : train loss 87.97146, val loss 219.32976, time 18.03s
# epoch 71 : train loss 87.90881, val loss 221.48219, time 17.99s
# epoch 72 : train loss 86.84898, val loss 218.78159, time 17.34s
# epoch 73 : train loss 87.34465, val loss 218.12342, time 17.54s
# epoch 74 : train loss 86.73830, val loss 217.93277, time 17.67s
# epoch 75 : train loss 87.30939, val loss 218.79288, time 17.95s
# Saving best model
# epoch 76 : train loss 87.02663, val loss 215.66098, time 18.26s
# epoch 77 : train loss 88.06974, val loss 220.31974, time 17.91s
# epoch 78 : train loss 88.57218, val loss 218.23619, time 18.01s
# epoch 79 : train loss 88.39387, val loss 218.46613, time 17.90s
# epoch 80 : train loss 87.55705, val loss 216.81135, time 17.48s
# epoch 81 : train loss 86.64927, val loss 218.25088, time 18.14s
# epoch 82 : train loss 88.43231, val loss 218.27110, time 17.69s
# epoch 83 : train loss 87.05695, val loss 219.95039, time 19.11s
# epoch 84 : train loss 87.26342, val loss 217.34345, time 18.42s
# epoch 85 : train loss 88.10368, val loss 218.23997, time 18.51s
# epoch 86 : train loss 87.17311, val loss 217.67672, time 17.85s
# epoch 87 : train loss 86.83700, val loss 217.59624, time 17.90s
# epoch 88 : train loss 88.21572, val loss 219.63842, time 18.52s
# epoch 89 : train loss 87.97173, val loss 218.85661, time 18.50s
# epoch 90 : train loss 87.34536, val loss 216.70312, time 17.76s
# epoch 91 : train loss 87.78787, val loss 216.45118, time 17.61s
# epoch 92 : train loss 87.45392, val loss 218.16922, time 17.89s
# epoch 93 : train loss 87.21024, val loss 217.03498, time 17.77s
# epoch 94 : train loss 87.09377, val loss 220.59284, time 17.21s
# epoch 95 : train loss 87.07244, val loss 215.70447, time 17.70s
# epoch 96 : train loss 88.67763, val loss 218.79485, time 18.45s
# epoch 97 : train loss 87.57789, val loss 216.31247, time 18.15s
# epoch 98 : train loss 87.82835, val loss 216.01483, time 17.63s
# epoch 99 : train loss 86.24697, val loss 216.97981, time 17.81s
# epoch 100 : train loss 86.55411, val loss 217.76915, time 17.47s
# epoch 101 : train loss 88.28754, val loss 216.82342, time 17.67s
# epoch 102 : train loss 86.58638, val loss 216.32025, time 16.94s
# epoch 103 : train loss 87.73413, val loss 216.53257, time 18.57s
# epoch 104 : train loss 87.67048, val loss 215.92780, time 18.18s
# epoch 105 : train loss 86.29354, val loss 216.16917, time 18.32s
# epoch 106 : train loss 86.86598, val loss 218.09224, time 17.69s
# Saving best model
# epoch 107 : train loss 86.94667, val loss 213.64692, time 17.67s
# epoch 108 : train loss 87.48584, val loss 217.39455, time 18.09s
# epoch 109 : train loss 87.07180, val loss 218.14847, time 18.77s
# epoch 110 : train loss 87.98000, val loss 218.77006, time 18.03s
# epoch 111 : train loss 87.57696, val loss 216.85574, time 18.25s
# epoch 112 : train loss 87.45709, val loss 214.30435, time 18.07s
# epoch 113 : train loss 86.66167, val loss 217.37139, time 18.21s
# Saving best model
# epoch 114 : train loss 86.85765, val loss 213.63248, time 18.13s
# epoch 115 : train loss 87.03608, val loss 214.10338, time 17.87s
# epoch 116 : train loss 87.74411, val loss 214.95377, time 18.41s
# epoch 117 : train loss 86.93623, val loss 219.25824, time 17.40s
# epoch 118 : train loss 87.94239, val loss 218.59644, time 17.60s
# epoch 119 : train loss 87.29859, val loss 217.73815, time 17.77s
# epoch 120 : train loss 88.65314, val loss 217.03883, time 17.97s
# Saving best model
# epoch 121 : train loss 86.75109, val loss 213.53438, time 18.06s
# epoch 122 : train loss 87.17820, val loss 215.22984, time 17.67s
# epoch 123 : train loss 86.77024, val loss 214.52488, time 18.61s
# epoch 124 : train loss 87.54251, val loss 215.15880, time 18.40s
# epoch 125 : train loss 88.59455, val loss 215.71595, time 18.02s
# epoch 126 : train loss 87.63766, val loss 216.16951, time 18.45s
# epoch 127 : train loss 87.02928, val loss 214.33484, time 18.85s
# epoch 128 : train loss 87.09516, val loss 217.92399, time 17.70s
# epoch 129 : train loss 86.96922, val loss 216.40424, time 18.89s
# epoch 130 : train loss 87.13474, val loss 217.42142, time 18.36s
# Saving best model
# epoch 131 : train loss 87.24344, val loss 212.81228, time 18.55s
# epoch 132 : train loss 87.55147, val loss 216.54102, time 18.37s
# epoch 133 : train loss 87.09420, val loss 214.00798, time 18.80s
# epoch 134 : train loss 86.58100, val loss 217.14367, time 17.89s
# epoch 135 : train loss 87.29443, val loss 217.00749, time 17.61s
# epoch 136 : train loss 87.55792, val loss 216.46313, time 18.08s
# epoch 137 : train loss 87.04649, val loss 215.37845, time 17.73s
# epoch 138 : train loss 86.32940, val loss 214.87840, time 18.21s
# epoch 139 : train loss 87.23501, val loss 216.41656, time 18.12s
# epoch 140 : train loss 86.42209, val loss 215.28681, time 17.44s
# epoch 141 : train loss 86.97048, val loss 214.34793, time 17.47s
# epoch 142 : train loss 87.02499, val loss 214.52787, time 17.49s
# epoch 143 : train loss 86.71870, val loss 215.39582, time 18.49s
# epoch 144 : train loss 88.12114, val loss 215.28753, time 17.67s
# epoch 145 : train loss 86.29671, val loss 215.70117, time 18.03s
# epoch 146 : train loss 86.95472, val loss 215.57832, time 18.16s
# epoch 147 : train loss 87.49304, val loss 214.86017, time 18.12s
# epoch 148 : train loss 86.73956, val loss 215.50368, time 17.38s
# epoch 149 : train loss 87.47353, val loss 213.67498, time 18.18s
# epoch 150 : train loss 87.39819, val loss 215.90590, time 17.93s
# epoch 151 : train loss 87.73281, val loss 215.26683, time 18.01s
# epoch 152 : train loss 86.98691, val loss 215.44673, time 17.86s
# epoch 153 : train loss 87.74422, val loss 216.76906, time 17.77s
# epoch 154 : train loss 86.61067, val loss 214.07350, time 17.66s
# epoch 155 : train loss 87.11367, val loss 215.40544, time 17.76s
# epoch 156 : train loss 87.03626, val loss 215.43955, time 18.63s
# epoch 157 : train loss 87.01998, val loss 215.57193, time 17.71s
# epoch 158 : train loss 87.92006, val loss 216.99533, time 17.89s
# epoch 159 : train loss 87.77279, val loss 215.75067, time 17.67s
# epoch 160 : train loss 87.12876, val loss 215.75030, time 17.43s
# epoch 161 : train loss 87.40675, val loss 214.82868, time 18.09s
# epoch 162 : train loss 87.20411, val loss 216.37657, time 17.75s
# epoch 163 : train loss 86.79870, val loss 214.19441, time 17.83s
# epoch 164 : train loss 87.97381, val loss 219.40710, time 17.47s
# epoch 165 : train loss 87.14847, val loss 216.28034, time 18.01s
# epoch 166 : train loss 87.22334, val loss 217.23995, time 17.88s
# epoch 167 : train loss 88.04454, val loss 214.79975, time 17.20s
# epoch 168 : train loss 87.55877, val loss 216.37917, time 17.40s
# epoch 169 : train loss 86.46168, val loss 216.61798, time 17.85s
# epoch 170 : train loss 86.56663, val loss 214.41366, time 17.93s
# epoch 171 : train loss 87.59950, val loss 213.78573, time 17.53s
# epoch 172 : train loss 87.92344, val loss 216.83931, time 17.96s
# epoch 173 : train loss 88.24163, val loss 216.34607, time 17.92s
# epoch 174 : train loss 86.86234, val loss 213.41189, time 17.37s
# epoch 175 : train loss 86.55263, val loss 217.01666, time 17.47s
# epoch 176 : train loss 87.07514, val loss 215.63434, time 18.13s
# epoch 177 : train loss 86.81097, val loss 216.29711, time 16.93s
# epoch 178 : train loss 87.03881, val loss 214.77219, time 17.26s
# epoch 179 : train loss 87.60456, val loss 216.68071, time 17.14s
# epoch 180 : train loss 87.01418, val loss 216.57622, time 17.49s
# epoch 181 : train loss 86.85040, val loss 219.53761, time 17.53s
# epoch 182 : train loss 87.76082, val loss 215.06216, time 17.40s
# epoch 183 : train loss 87.48689, val loss 215.90722, time 18.56s
# epoch 184 : train loss 87.58503, val loss 213.72189, time 17.64s
# epoch 185 : train loss 86.29648, val loss 215.97305, time 17.62s
# epoch 186 : train loss 86.64456, val loss 217.96779, time 17.81s
# epoch 187 : train loss 86.50326, val loss 214.81368, time 17.68s
# epoch 188 : train loss 87.33489, val loss 215.49831, time 17.46s
# epoch 189 : train loss 87.01146, val loss 218.44403, time 17.71s
# epoch 190 : train loss 86.66240, val loss 216.17132, time 18.36s
# epoch 191 : train loss 86.61899, val loss 216.60354, time 17.29s
# epoch 192 : train loss 87.65199, val loss 216.89143, time 17.18s
# epoch 193 : train loss 87.70222, val loss 216.48639, time 17.44s
# epoch 194 : train loss 87.87635, val loss 214.12499, time 17.91s
# epoch 195 : train loss 87.55281, val loss 216.14320, time 17.40s
# epoch 196 : train loss 87.32797, val loss 216.11890, time 17.13s
# epoch 197 : train loss 86.49721, val loss 215.78579, time 17.88s
# epoch 198 : train loss 87.33116, val loss 214.52407, time 17.56s
# epoch 199 : train loss 87.24468, val loss 215.28344, time 17.95s

# %%
import time
import torch
import torchvision
from torchvision.transforms import *
import torch.nn.functional as F
from PIL import Image

batch_size=64

class MyDataset(torch.utils.data.Dataset):
    def __init__(self, dataframe):
        self.dataframe = dataframe

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, index):
        row = self.dataframe.iloc[index]
        c = torchvision.transforms.Compose([Grayscale(),
                                            RandomHorizontalFlip(),
                                            RandomPerspective(),
                                            RandomRotation(degrees=(0, 180)),
                                            RandomVerticalFlip(),
                                            Resize((96,96)),
                                            functional.to_tensor])
        return (
            c(Image.open("../datasets/datasets_train/train/"+row["im_name"])),
            row["Average of CO2 (g per km)"],
        )

dataset = MyDataset(df)

train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size

train_set, val_set = torch.utils.data.random_split(dataset, [train_size, test_size])

train_loader = torch.utils.data.DataLoader(dataset=train_set, batch_size=batch_size)
test_loader = torch.utils.data.DataLoader(dataset=val_set, batch_size=batch_size)

class ConvNet(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(1, 3, 3, padding='same')
        self.pool = torch.nn.MaxPool2d(2, 2)
        self.conv2 = torch.nn.Conv2d(3, 6, 3, padding='same')
        self.conv3 = torch.nn.Conv2d(6, 12, 3, padding='same')
        self.fc = torch.nn.Linear(1728, 1)
        self.dropout = torch.nn.Dropout()


    def forward(self, x):
        x = x.view(-1,1,96,96)
        x = self.dropout(self.pool(F.relu(self.conv1(x))))
        x = self.dropout(self.pool(F.relu(self.conv2(x))))
        x = self.dropout(self.pool(F.relu(self.conv3(x))))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = self.fc(x)
        return x

my_model = ConvNet()

optimizer = torch.optim.Adam(my_model.parameters(), lr=3e-4)
# optimizer = torch.optim.SGD(model.parameters(), lr=0.5e-1)

criterion = torch.nn.MSELoss()

loss_l_train = []
loss_l_val = []
nb_epoch = 200

for num_epoch in range(nb_epoch):
    t0 = time.time()
    my_model.train()
    running_loss = 0
    total = 0
    for i, (inputs, labels) in enumerate(train_loader):
        outputs = my_model(inputs) # Forward pass: Compute predicted y by passing  x to the model          
        labels = labels.unsqueeze(1).float()
        loss = criterion(outputs,labels) # Compute loss 

        optimizer.zero_grad() # re-init the gradients (otherwise they are cumulated)
        loss.backward() # perform back-propagation
        optimizer.step() # update the weights

        running_loss += loss.item()
        
        total += labels.size(0)

    loss_l_train.append(running_loss/total)

    my_model.eval()
    running_loss_val = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            outputs = my_model(inputs)  
            labels = labels.unsqueeze(1).float()
            loss = criterion(outputs,labels)

            running_loss_val += loss.item()

            total += labels.size(0)

    loss_l_val.append(running_loss_val/total)

    if loss_l_val[-1] == min(loss_l_val):
        print("Saving best model")
        torch.save(my_model, 'models/best-reg.pt')
        torch.save(my_model.state_dict(), 'models/best-reg-parameters.pt')

    print(f'epoch {num_epoch} : train loss {loss_l_train[-1]:.5f}, val loss {loss_l_val[-1]:.5f}, time {time.time()-t0:.2f}s')
